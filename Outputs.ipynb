# %% [markdown]
# 1.Identify the primary keys and foreign keys in maven movies db. Discuss the differences

# %% [markdown]
# ![1.png](attachment:448ad146-c9df-458e-a1f6-0baede365836.png)

# %% [markdown]
# 2.List all details of actors

# %% [markdown]
# ![2.png](attachment:b0513372-3dce-4d6e-80bd-7ea1231aedf7.png)
